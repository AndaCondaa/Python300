# %%
#71
my_variable = ()
print(type(my_variable))
# Out:
# <class 'tuple'>

# %%
#71
movie_rank = ("닥터 스트레인지", "스플릿", "럭키")
print(movie_rank)
print(type(movie_rank))
# Out:
# ('닥터 스트레인지', '스플릿', '럭키')
# <class 'tuple'>
