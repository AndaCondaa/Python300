# %%
#21 인덱싱
letters = 'python'
print(letters[0], letters[2])
# Out:
# p t

# %%
#22    ->>>> 음수 인덱싱은 가장 뒤쪽 인덱스 번호가 -1!!!!! 양수로 인덱싱 할 때, 첫번째 글자가 0인 것과 다름
num = "24가 2210"
print(num[-4:])
# Out:
# 2210

# %%
#23 슬라이싱   ->>>> [시작인덱스:끝인덱스:오프셋]
string = '홀짝홀짝홀짝'
print(string[::2])
# Out:
# 홀홀홀

# %%
#24
string = 'PYTHON'
print(string[::-1])
# Out:
# NOHTYP

# %%
#25 ->>> replace 메서드: 문자열 치환
num = '010-1111-2222'
num_t = num.replace('-',' ')
print(num_t)
# Out:
# 010 1111 2222

# %%
#26
num_r = num_t.replace(' ','')
print(num_r)
# Out:
# 01011112222

# %%
#27 ->>>> split 메서드
url = 'http://sharebook.kr'
url_s = url.split('.')
print(url_s)
print(url_s[-1])
# Out:
# ['http://sharebook', 'kr']
# kr

# %%
#28 ->>> 문자열은 수정할 수 없음 
lang = 'python'
lang[0] = 'P'
print(lang)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 #28
#       2 lang = 'python'
# ----> 3 lang[0] = 'P'
#       4 print(lang)
#
# TypeError: 'str' object does not support item assignment

# %%
#29
string = 'abcdefe2a354a43a'
string = string.replace('a','A')
print(string)
# Out:
# Abcdefe2A354A43A

# %%
#30   ->>> replace 메서드는 원래의 변수가 변하지 않음, 문자열은 변경할 수 없는 자료형이기 떄문
string = 'abcd'
string.replace('b', 'B')
print(string)
# Out:
# abcd
