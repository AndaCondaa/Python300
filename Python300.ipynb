# %% [markdown]
# 파이썬 300제

# %%
#1
print("Hello World")
# Out:
# Hello World

# %%
#2
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
#3
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
#4
print('"C:\Windows"')
# Out:
# "C:\Windows"

# %%
#5
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
#6
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
#7  ->> sep 인자로 ";"를 입력하면 출력되는 값들 사이에 한 칸의 공백대신 세미콜론이 출력
print("naver;kakao;sk;samsung")
print("naver","kakao","sk","samsung",sep=";")
# Out:
# naver;kakao;sk;samsung
# naver;kakao;sk;samsung

# %%
#8
print("naver","kakao","sk","samsung",sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
#9 ->> 세미콜론은 한줄에 여러 개의 명령을 작성하기 위해 사용
print("first");print("second")
print("first",end=""); print("second")
#파이썬은 기본적으로 print 함수 다음에 \n이 붙기 때문에 첫번째 코드에서 실행 결과가 두 줄로 출력된다. 한 줄로 출력하고 싶다면, end="" 사용
# Out:
# first
# second
# firstasdfsecond

# %%
#10
print(5/3)
# Out:
# 1.6666666666666667

# %%
#11
삼성전자 = 50000
총평가금액 = 삼성전자 * 10
print(총평가금액)
# Out:
# 500000

# %%
#12
시가총액 = 298
현재가 = 500000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 298 <class 'int'>
# 500000 <class 'int'>
# 15.79 <class 'float'>

# %%
#13 ->> 문자열 + 문자열 가능!
s = "hello"
t = "python"
print(s, t, sep="!")
print(s+"!", t)
# Out:
# hello!python
# hello! python

# %%
#14
2 + 2 * 3
# Out:
# 8

# %%
#15
a = 123
b = "123"
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#16
num_str = "720"
print(type(num_str))
print(num_str)
num = int(num_str)
print(type(num))
print(num)
# Out:
# <class 'str'>
# 720
# <class 'int'>
# 720

# %%
#17
num = 100
num_str = str(num)
print(num_str, type(num_str))
# Out:
# 100 <class 'str'>

# %%
#18
a = "15.79"
print(a, type(a))
b = float(a)
print(b, type(b))
# Out:
# 15.79 <class 'str'>
# 15.79 <class 'float'>

# %%
#19
year = "2020"
trans = int(year)
print("최근 3개년:", trans, trans+1, trans+2)
# Out:
# 최근 3개년: 2020 2021 2022

# %%
#20
price = 48584
month = 36
total = price * month
print(total)
# Out:
# 1749024
