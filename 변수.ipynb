# %%
#11
삼성전자 = 50000
총평가금액 = 삼성전자 * 10
print(총평가금액)
# Out:
# 500000

# %%
#12
시가총액 = 298
현재가 = 500000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 298 <class 'int'>
# 500000 <class 'int'>
# 15.79 <class 'float'>

# %%
#13 ->> 문자열 + 문자열 가능!
s = "hello"
t = "python"
print(s, t, sep="!")
print(s+"!", t)
# Out:
# hello!python
# hello! python

# %%
#14
2 + 2 * 3
8
#15
a = 123
b = "123"
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#16
num_str = "720"
print(type(num_str))
print(num_str)
num = int(num_str)
print(type(num))
print(num)
# Out:
# <class 'str'>
# 720
# <class 'int'>
# 720

# %%
#17
num = 100
num_str = str(num)
print(num_str, type(num_str))
# Out:
# 100 <class 'str'>

# %%
#18
a = "15.79"
print(a, type(a))
b = float(a)
print(b, type(b))
# Out:
# 15.79 <class 'str'>
# 15.79 <class 'float'>

# %%
#19
year = "2020"
trans = int(year)
print("최근 3개년:", trans, trans+1, trans+2)
# Out:
# 최근 3개년: 2020 2021 2022

# %%
#20
price = 48584
month = 36
total = price * month
print(total)
# Out:
# 1749024
